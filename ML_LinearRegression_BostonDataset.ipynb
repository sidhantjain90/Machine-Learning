# %% [markdown]
# # Machine Learning : Linear Regression ( Boston Housing )

# %% [markdown]
# - This notebook contains the machine learning model trained and evaluated on Boston Housing dataset. The objective is to predict the price of the housing in Boston and study/analyse the influence of different variables on the pricing.
# - The dataset was a part of UCI Machine Learning Repository and now present in sklearn datasets. It contains 13 feature variables and 506 observations

# %% [markdown]
# Importing the usual suspects

# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from sklearn.datasets import load_boston
boston = load_boston()

# %% [markdown]
# Boston housing dataset contains information about different houses in Boston.

# %% [markdown]
#  To see the description of various variables in the dataset

# %%
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %% [markdown]
# From the dataset it could be infered that MEDV is the price of the housing or target variable and other variables are the feature variables.

# %% [markdown]
# Printing the value of boston dataset to understand what it contains

# %%
print(boston.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %% [markdown]
# Create a dataframe using 'data' for data and 'feature_names' for column names

# %%
Boston_df = pd.DataFrame(data = boston.data, columns=boston.feature_names)

# %% [markdown]
# Check the head of the dataframe created

# %%
Boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
Boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
# dtypes: float64(13)
# memory usage: 51.5 KB

# %% [markdown]
# It can be observed that the target value is missing in the data. We can create a new column in Boston_df as MEDV

# %%
Boston_df['MEDV'] = boston.target

# %%
Boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
Boston_df['MEDV'].describe()
# Out:
# count    506.000000
# mean      22.532806
# std        9.197104
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: MEDV, dtype: float64

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# Check for null values in the data

# %%
Boston_df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# - Firstly we will plot the distribution of the target variable MEDV using distplot from seaborn

# %%
plt.figure(figsize=(10,6))
sns.distplot(Boston_df['MEDV'], bins=30)

# %% [markdown]
# - Next, we will try to check the relationship or correlation among all the variables using heatmap from seaborn

# %%
plt.figure(figsize=(10,6))
sns.heatmap(Boston_df.corr(), annot=True, cmap='coolwarm')

# %% [markdown]
# From the heatmap above it seems there is a good correlation between MEDV and the feature variables LSTAT (-0.74), PTRATIO(-0.51) and RM (0.7)

# %% [markdown]
# - 'RM' is the average number of rooms among homes in the neighborhood.
# - 'LSTAT' is the percentage of homeowners in the neighborhood considered "lower class" (working poor).
# - 'PTRATIO' is the ratio of students to teachers in primary and secondary schools in the neighborhood.

# %% [markdown]
# - Since the above three variables are major influencers for the pricing of the house we will continue with these 3 variables and drop others.

# %% [markdown]
#  Let's check the correlations of these feature variables with pricing (MEDV) variable

# %%
plt.figure(figsize=(20,5))

features = ['RM', 'LSTAT', 'PTRATIO']

for i, col in enumerate(features):
    plt.subplot(1, 3, i+1)
    
    x = Boston_df['MEDV']
    y = Boston_df[col]
    
    plt.scatter(x, y)
    plt.ylabel(col)
    plt.xlabel('MEDV')
    plt.title(col)

# %% [markdown]
# ## Training a Linear Regression Model

# %% [markdown]
# - Prepare the data for training with a Linear Regression Model

# %%
X = Boston_df[['RM', 'PTRATIO', 'LSTAT']]
y = Boston_df['MEDV']

# %% [markdown]
# ## Train Test Split

# %% [markdown]
# - The data shall be split into training to train the model and testing for evaluating the model's performance

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Creating and training the Linear Regression model

# %% [markdown]
# - Import the Linear Regression model from sklearn
# - Create an instance of the model 'lm'
# - fit the model on training data

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## Evaluation of model's performance

# %% [markdown]
# - Let's evaluate the model by checking out the coefficients and how we can interpret them

# %%
# print the intercept
lm.intercept_
# Out:
# 18.119085045192005

# %%
coeff_df = pd.DataFrame(lm.coef_, X.columns, columns=['Coefficient'])
coeff_df
# Out:
#          Coefficient
# RM          4.461626
# PTRATIO    -0.862905
# LSTAT      -0.608150

# %% [markdown]
# #### Interpretation:
#
# - Holding all other features fixed, an unit increase in Avg. number of rooms (RM) is associated with an increase of \$4.46
# - Holding all other features fixed, an unit increase in the ratio of students to teachers in primary and secondary schools (PTRATIO) is associated with a decrease of \$0.86
# - Holding all other features fixed, an unit increase in the percentage of homeowners in the neighborhood considered "lower class" (LSTAT) with a decrease of \$0.60

# %% [markdown]
# ## Predictions from trained model

# %%
predictions = lm.predict(X_test)

# %% [markdown]
#  Plotting the predictions vs actual y (test) values

# %%
#plt.scatter(y_test,y_test, color='b')
fit = np.poly1d(np.polyfit(y_test, y_test, 1))
lim = np.linspace(min(y_test)-1,max(y_test)+1)
plt.plot(lim, fit(lim), alpha=0.3, color='black')
plt.scatter(y_test, predictions, color='r')

# %% [markdown]
# - The above scatter plot shows the presence of certain error between predicted and actual values since ideally this should have been a straight line.
#
# - Let's check how bad is the error between them by observing a residual histogram.

# %%
sns.distplot((y_test-predictions), bins=50)

# %% [markdown]
# - Another way is to evaluate RMSE and $R^2$

# %%
# import MSE and R2
from sklearn.metrics import mean_squared_error, r2_score

# %%
#RMSE
rmse = np.sqrt(mean_squared_error(y_test, predictions))
# Out:
# 5.100216850500208

# %%
#R_2
r2 = r2_score(y_test, predictions)

# %%
print('Performance Metrics')
print('\n')
print("RMSE is : {}".format(rmse))
print("R2 score is : {}".format(r2))
# Out:
# Performance Metrics
#
#
# RMSE is : 5.100216850500208
# R2 score is : 0.650904156861472

# %% [markdown]
# - r2 score of 0.65 means that about $65\%$ of variance of 'y_test' is predicted from 'predictions'.
